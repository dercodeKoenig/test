# %% [markdown]
# <a href="https://colab.research.google.com/github/dercodeKoenig/test/blob/main/object_detection_start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile kaggle.json
# {"username":"lutze3","key":"c1b954a36f5402b976973271cb154a2f"}

# %%
# !pip install kaggle tensorflow opencv-python matplotlib

# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle
# !mkdir images
# !kaggle datasets download -d shamsaddin97/image-captioning-dataset-random-images
# !unzip image-captioning-dataset-random-images.zip
# !rm image-captioning-dataset-random-images.zip
# !kaggle datasets download -d bpwqsdd/hand-samples
# !mkdir hand_samples
# !mv hand-samples.zip hand_samples
# %cd hand_samples
# !unzip hand-samples.zip
# !rm hand-samples.zip
# %cd ..

import IPython
IPython.display.clear_output()
