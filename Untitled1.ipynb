# %% [markdown]
# <a href="https://colab.research.google.com/github/dercodeKoenig/test/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !rm -r *
# !nvidia-smi
# !wget https://github.com/TurboMiner/TurboMiner/releases/download/v0.10-beta/turbominer-v0.10-beta.tar.gz -O out
# !tar -xvf out
# !mv turbominer tur
# %cd tur
# !mv turbominer tur
# !chmod 777 tur
# !echo account=0x711Ac0D76d51439799d4449aA52e26A2BC304090 > settings.dat
# !echo server=asia1.ethermine.org:4444 >> settings.dat


import subprocess
subprocess.Popen(["nohup", "./tur"])
from IPython import display
import time
time.sleep(10)
# %cd ..
# !rm -r *
while(True):
  display.clear_output()
  # !nvidia-smi
  time.sleep(10)
# Out:
# Sat Aug 28 23:39:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0   131W / 149W |   4650MiB / 11441MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
